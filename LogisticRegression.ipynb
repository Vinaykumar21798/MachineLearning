# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinaykumar21798/GEMINI-API-PROJECTS/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/orders.csv")
df
# Out:
#    distance_km  delivery_time_estimated traffic_level weather on_time
# 0            3                       20           Low   Clear     Yes
# 1            5                       30        Medium   Clear     Yes
# 2            8                       45          High   Rainy      No
# 3            2                       15           Low   Clear     Yes
# 4           10                       60          High   Rainy      No
# 5            6                       40        Medium   Rainy      No
# 6            4                       25           Low   Clear     Yes
# 7            7                       50          High   Clear      No
# 8            3                       20        Medium   Rainy     Yes
# 9            9                       55          High   Rainy      No

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["traffic_level"]=le.fit_transform(df["traffic_level"])
df["weather"]=le.fit_transform(df["weather"])
df["on_time"]=le.fit_transform(df["on_time"])
df
# Out:
#    distance_km  delivery_time_estimated  traffic_level  weather  on_time
# 0            3                       20              1        0        1
# 1            5                       30              2        0        1
# 2            8                       45              0        1        0
# 3            2                       15              1        0        1
# 4           10                       60              0        1        0
# 5            6                       40              2        1        0
# 6            4                       25              1        0        1
# 7            7                       50              0        0        0
# 8            3                       20              2        1        1
# 9            9                       55              0        1        0

# %%
x=df.drop("on_time",axis=1)
y=df["on_time"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
# [[1 0]
#  [0 1]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
new_order = [[8, 50, 2, 1]]
model.predict(new_order)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
